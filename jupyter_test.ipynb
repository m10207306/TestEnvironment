# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.0.1

# %%
# DataFrame Initialization
dic = \
	{
		"col 1": [1, 2, 3],
		"col 2": [10, 20, 30],
		"col 3": list("xyz"),
		"col 4": pd.Series(range(3)),
	}

df = pd.DataFrame(dic)
df

# %%
# Column Rename
rename_col = {"col 1": "x", "col 2": "10x"}
df.rename(rename_col, axis = 1, inplace = True)
df

df.columns = ["x(new)", "10x(new)"] + list(df.columns[2:])
df

# %%
# Create Random DataFrame
print(pd.util.testing.makeDataFrame().shape)
# Create Random DataFrame with Mixed DataType
print(pd.util.testing.makeMixedDataFrame().shape)

# %%
# I/O of DataFrame
# df.to_csv("file.csv")
# df = pd.read_csv("file path or http address")

# %%
# Memory Usage of DataFrame
df.info(memory_usage = "deep")

# %%
# DataFrame Combination
df = pd.concat([pd.read_csv(f) for f in file_list]) # combine a list of dataframes (default axis = 0)
#				[df1, df2, df3...]
df.reset_index(drop = True, inplace = True)		# drop the orginal index column created from reset_index function

dic1 = \
	{
		"PassengerID": [1, 2, 3],
		"Survived": [0, 1, 1],
		"Pclass": [8, 1, 8],
		"Name": ["Braund", "Cumings", "Heikkinen"],
	}
df1 = pd.DataFrame(dic1)

dic2 = \
	{
		"Sex": ["male", "female", "female"],
		"Age": [22, 88, 26],
	}
df2 = pd.DataFrame(dic2)

df = pd.concat([df1, df2], axis = 1)
print(df)

# %%
# Global Display Option
pd.set_option("display.max_columns", None)	# remove the limit number to show column
pd.get_option("display.max_colwidth")		# get display length of column
pd.set_option("display.max_colwidth", 10)	# set display length of column
pd.set_option("display.precision", 1)
pd.reset_option("all")
pd.describe_option()						# display available options

# %%
# if we want to set the specific dataframe, use datafrome.style
df_sample = pd.read_csv("Titanic.csv")

df_sample.style\
	.format('{:.1f}', subset='Fare')\
	.set_caption('★五顏六色の鐵達尼號數據集☆')\
	.hide_index()\
	.bar('Age', vmin=0)\
	.highlight_max('Survived')\
	.background_gradient('Greens', subset='Fare')\
	.highlight_null()
# Out:
# <style  type="text/css" >
#     #T_52415a78_f331_11ea_bf83_d017c2cb8594row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.5%, transparent 27.5%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row0_col9 {
#             background-color:  #f5fbf3;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row0_col10 {
#             background-color:  red;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row1_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.5%, transparent 47.5%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row1_col9 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.5%, transparent 32.5%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row2_col9 {
#             background-color:  #f5fbf3;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row2_col10 {
#             background-color:  red;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.7%, transparent 43.7%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row3_col9 {
#             background-color:  #e8f6e4;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.7%, transparent 43.7%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row4_col9 {
#             background-color:  #f5fbf2;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row4_col10 {
#             background-color:  red;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row5_col5 {
#             : ;
#             background-color:  red;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row5_col9 {
#             background-color:  #f5fbf2;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row5_col10 {
#             background-color:  red;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row6_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 67.5%, transparent 67.5%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row6_col9 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row7_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.5%, transparent 2.5%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row7_col9 {
#             background-color:  #f1faee;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row7_col10 {
#             background-color:  red;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row8_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row8_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.7%, transparent 33.7%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row8_col9 {
#             background-color:  #f4fbf2;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row8_col10 {
#             background-color:  red;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row9_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row9_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.5%, transparent 17.5%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row9_col9 {
#             background-color:  #eff9eb;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row9_col10 {
#             background-color:  red;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row10_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row10_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.0%, transparent 5.0%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row10_col9 {
#             background-color:  #f2faf0;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row11_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row11_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 72.5%, transparent 72.5%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row11_col9 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row12_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.0%, transparent 25.0%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row12_col9 {
#             background-color:  #f5fbf2;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row12_col10 {
#             background-color:  red;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row13_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.7%, transparent 48.7%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row13_col9 {
#             background-color:  #eff9eb;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row13_col10 {
#             background-color:  red;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row14_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.5%, transparent 17.5%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row14_col9 {
#             background-color:  #f5fbf3;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row14_col10 {
#             background-color:  red;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row15_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row15_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 68.7%, transparent 68.7%);
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row15_col9 {
#             background-color:  #f3faf0;
#             color:  #000000;
#             : ;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row15_col10 {
#             background-color:  red;
#         }    #T_52415a78_f331_11ea_bf83_d017c2cb8594row16_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.5%, t

# %%
# Random Sampling
df_sample = df.sample(n=10, random_state = 9527).drop("name", axis = 1)

# %%
# Transpose
df.T

# %%
# Fill Nan/None
df.fillna(0)
df.fillna("unknown")

# %%
# Delete Column/Row
columns = ["col 1", "col 2"]
df.drop(columns, axis = 1)

df.drop("Name", axis = 1, inplace = True)
df.drop(0, axis = 0, inplace = True)

# %%
# Split String in Column into New Columns
df = pd.DataFrame({
	"name": ["大雄", "胖虎"], 
    "feature": ["膽小, 翻花繩", "粗魯, 演唱會"]
	})

df[["性格", "特技"]] = df["feature"].str.split(",", expand = True)
df
# Out:
#   name  feature  性格    特技
# 0   大雄  膽小, 翻花繩  膽小   翻花繩
# 1   胖虎  粗魯, 演唱會  粗魯   演唱會

# %%
# Split List in Column into New Columns
df = pd.DataFrame({
    "name": ["大雄", "胖虎"], 
    "feature": [["膽小", "翻花繩"], ["粗魯", "演唱會"]]
})

cols = ["性格", "特技"]
df[["性格", "特技"]] = pd.DataFrame(df.feature.tolist())
# df[["性格", "特技"]] = df.feature.apply(pd.Series)
df
# Out:
#   name    feature  性格   特技
# 0   大雄  [膽小, 翻花繩]  膽小  翻花繩
# 1   胖虎  [粗魯, 演唱會]  粗魯  演唱會

# %%
# Slice of DataFrame
df = pd.read_csv("Titanic.csv")

df.loc[:3, "Pclass":"Ticket"]    # .loc is using tag to slice
df.iloc[:3, 2:7]                 # .iloc is using index to slice
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
#
#    SibSp
# 0      1
# 1      1
# 2      0

# %%
# Mask of DataFrame

# find the specific condition data - method1
bool_series = (df["Sex"] == "male") & (df["Age"] > 70)
df[bool_series]

# find the specific condition data - method 2
age = 70
df.query("Age > @age & Sex == 'male'")    # @ will access the variable has defined already

# find None 
df[df.isnull().any(axis = 1)].head()
# isnull() return boolean dataframe
# any() return row index containing true, axis = 1 return column index

# include or exclude specific datatype from dataframe
df.select_dtypes(include = ["number"]).head()
df.select_dtypes(exclude = ["object"]).head()  # exclude strings

#
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500
